# %% [markdown]
# #### This notebook is where we will extract the pertinent weather data for the flights training data set

# %%
# Import pandas for df manipulations
import pandas as pd 

from functions import get_hour, time_of_day

# %%
# Load the datasets
weather = pd.read_csv('data/WeatherEvents_Jan2016-Dec2020.csv')
data = pd.read_csv('data/flights.csv', low_memory = False)

# %%
# Inspect the data dataframe
data.head()
# Out:
#    Unnamed: 0     fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0           0  2018-12-15                 NK                 NK          NK
# 1           1  2018-12-16                 UA       UA_CODESHARE          UA
# 2           2  2018-12-15                 NK                 NK          NK
# 3           3  2018-12-15                 NK                 NK          NK
# 4           4  2018-12-15                 NK                 NK          NK
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                 393                NK   N506NK                393
# 1                4119                EV   N14993               4119
# 2                 443                NK   N681NK                443
# 3                 445                NK   N504NK                445
# 4                 446                NK   N621NK                446
#
#    origin_airport_id  ... distance carrier_delay  weather_delay nas_delay  \
# 0              10397  ...    425.0           NaN            NaN       NaN
# 1              11618  ...    277.0           NaN            NaN       NaN
# 2              10821  ...    925.0           NaN            NaN       NaN
# 3              11066  ...    973.0           NaN            NaN       NaN
# 4              12889  ...   1514.0           NaN            NaN       NaN
#
#   security_delay  late_aircraft_delay  first_dep_time  total_add_gtime  \
# 0            NaN                  NaN             NaN              NaN
# 1            NaN                  NaN             NaN              NaN
# 2            NaN                  NaN             NaN              NaN
# 3            NaN                  NaN             NaN              NaN
# 4            NaN                  NaN             NaN              NaN
#
#    longest_add_gtime  no_name
# 0                NaN      NaN
# 1                NaN      NaN
# 2                NaN      NaN
# 3                NaN      NaN
# 4                NaN      NaN
#
# [5 rows x 43 columns]

# %% [markdown]
# Need to make an hour column in data

# %%
# Create a column with the hour that the plane departs and arrives

data['dep_hour'] = data['crs_dep_time'].apply(get_hour)
data['arr_hour'] = data['crs_arr_time'].apply(get_hour)
data['arr_hour'].dtypes
# Out:
# dtype('int64')

# %%
# Create a column that assigns a period of the day to a departure
data['dep_period'] = data['dep_hour'].apply(time_of_day)
data['arr_period'] = data['arr_hour'].apply(time_of_day)
data['arr_period'].value_counts()
# Out:
# Afternoon    484247
# Evening      439478
# Morning      369087
# Night         35861
# Name: arr_period, dtype: int64

# %%
data.head()
# Out:
#    Unnamed: 0     fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0           0  2018-12-15                 NK                 NK          NK
# 1           1  2018-12-16                 UA       UA_CODESHARE          UA
# 2           2  2018-12-15                 NK                 NK          NK
# 3           3  2018-12-15                 NK                 NK          NK
# 4           4  2018-12-15                 NK                 NK          NK
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                 393                NK   N506NK                393
# 1                4119                EV   N14993               4119
# 2                 443                NK   N681NK                443
# 3                 445                NK   N504NK                445
# 4                 446                NK   N621NK                446
#
#    origin_airport_id  ... security_delay late_aircraft_delay  first_dep_time  \
# 0              10397  ...            NaN                 NaN             NaN
# 1              11618  ...            NaN                 NaN             NaN
# 2              10821  ...            NaN                 NaN             NaN
# 3              11066  ...            NaN                 NaN             NaN
# 4              12889  ...            NaN                 NaN             NaN
#
#   total_add_gtime longest_add_gtime  no_name  dep_hour  arr_hour  dep_period  \
# 0             NaN               NaN      NaN        15        16   Afternoon
# 1             NaN               NaN      NaN        19        21     Evening
# 2             NaN               NaN      NaN        20        22     Evening
# 3             NaN               NaN      NaN         6         8     Morning
# 4             NaN               NaN      NaN         8        14     Morning
#
#    arr_period
# 0   Afternoon
# 1     Evening
# 2     Evening
# 3     Morning
# 4   Afternoon
#
# [5 rows x 47 columns]

# %%
# Build the matchcode variable for the data table
data['origin_match_code'] = data['origin'].astype(str) + data['fl_date'].astype(str) + data['dep_period'].astype(str)
data['dest_match_code'] = data['dest'].astype(str) + data['fl_date'].astype(str) + data['arr_period'].astype(str)

# %%
# Let's engineer some columns a little bit
weather['date'] = pd.DatetimeIndex(weather['StartTime(UTC)']).date
weather['hour'] = pd.DatetimeIndex(weather['StartTime(UTC)']).hour
weather['period'] = weather['hour'].apply(time_of_day)
weather = weather.drop(columns = ['StartTime(UTC)', 'EndTime(UTC)'])

# %%
# Remove the K prefix from the airport codes
weather['AirportCode'] = weather['AirportCode'].apply(lambda x: x[1:])

# %%
# Encode the match code column to match values to the data dataframe
weather['match_code'] = weather['AirportCode'].astype(str) + weather['date'].astype(str) + weather['period'].astype(str)

# %%
# Drop unnecessary columns

weather = weather.drop(columns = ['EventId',
                                  'TimeZone',
                                 'AirportCode',
                                 'LocationLat',
                                 'LocationLng',
                                 'City',
                                 'County',
                                 'State',
                                 'ZipCode'])

# %%
# Drop duplicate values
weather = weather.drop_duplicates(subset = 'match_code')
weather.shape
# Out:
# (3097656, 6)

# %%
# Create dictionaries for severity and condition with match_code as the key
severity_dict = dict(zip(weather['match_code'], weather['Severity']))
condition_dict = dict(zip(weather['match_code'], weather['Type']))

# %%
len(severity_dict)
# Out:
# 3097656

# %%
# Use the previously created dictionaries to add severity and condition to the flights dataset
data['origin_weather_condition'] = data['origin_match_code'].map(condition_dict)
data['origin_weather_severity'] = data['origin_match_code'].map(severity_dict)
data['dest_weather_condition'] = data['dest_match_code'].map(condition_dict)
data['dest_weather_severity'] = data['dest_match_code'].map(severity_dict)
data.head()
# Out:
#    Unnamed: 0     fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0           0  2018-12-15                 NK                 NK          NK
# 1           1  2018-12-16                 UA       UA_CODESHARE          UA
# 2           2  2018-12-15                 NK                 NK          NK
# 3           3  2018-12-15                 NK                 NK          NK
# 4           4  2018-12-15                 NK                 NK          NK
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                 393                NK   N506NK                393
# 1                4119                EV   N14993               4119
# 2                 443                NK   N681NK                443
# 3                 445                NK   N504NK                445
# 4                 446                NK   N621NK                446
#
#    origin_airport_id  ... dep_hour arr_hour  dep_period arr_period  \
# 0              10397  ...       15       16   Afternoon  Afternoon
# 1              11618  ...       19       21     Evening    Evening
# 2              10821  ...       20       22     Evening    Evening
# 3              11066  ...        6        8     Morning    Morning
# 4              12889  ...        8       14     Morning  Afternoon
#
#         origin_match_code         dest_match_code  origin_weather_condition  \
# 0  ATL2018-12-15Afternoon  MSY2018-12-15Afternoon                       NaN
# 1    EWR2018-12-16Evening    RIC2018-12-16Evening                      Rain
# 2    BWI2018-12-15Evening    FLL2018-12-15Evening                      Rain
# 3    CMH2018-12-15Morning    FLL2018-12-15Morning                       NaN
# 4    LAS2018-12-15Morning  ORD2018-12-15Afternoon                       NaN
#
#    origin_weather_severity  dest_weather_condition  dest_weather_severity
# 0                      NaN                     NaN                    NaN
# 1                 Moderate                     NaN                    NaN
# 2                    Light                    Rain                  Light
# 3                      NaN                     NaN                    NaN
# 4                      NaN                     NaN                    NaN
#
# [5 rows x 53 columns]

# %%
data.isna().sum()
# Out:
# Unnamed: 0                        0
# fl_date                           0
# mkt_unique_carrier                0
# branded_code_share                0
# mkt_carrier                       0
# mkt_carrier_fl_num                0
# op_unique_carrier                 0
# tail_num                       1355
# op_carrier_fl_num                 0
# origin_airport_id                 0
# origin                            0
# origin_city_name                  0
# dest_airport_id                   0
# dest                              0
# dest_city_name                    0
# crs_dep_time                      0
# dep_time                      10676
# dep_delay                     10968
# taxi_out                      11019
# wheels_off                    11012
# wheels_on                     11807
# taxi_in                       11814
# crs_arr_time                      0
# arr_time                      11807
# arr_delay                     14489
# cancelled                         0
# cancellation_code           1317461
# diverted                          0
# dup                               0
# crs_elapsed_time                  0
# actual_elapsed_time           14382
# air_time                      14382
# flights                           0
# distance                          0
# carrier_delay               1060875
# weather_delay               1060875
# nas_delay                   1060875
# security_delay              1060875
# late_aircraft_delay         1060875
# first_dep_time              1320181
# total_add_gtime             1320182
# longest_add_gtime           1320181
# no_name                     1328673
# dep_hour                          0
# arr_hour                          0
# dep_period                        0
# arr_period                        0
# origin_match_code                 0
# dest_match_code                   0
# origin_weather_condition    1018375
# origin_weather_severity     1018375
# dest_weather_condition      1024460
# dest_weather_severity       1024460
# dtype: int64

# %%
# Replace NaN weather conditions with 'Clear' and severity with 'Light'
data['origin_weather_condition'].fillna('Clear', inplace=True)
data['origin_weather_severity'].fillna('Light', inplace=True)
data['dest_weather_condition'].fillna('Clear', inplace=True)
data['dest_weather_severity'].fillna('Light', inplace=True)
data.head()
# Out:
#    Unnamed: 0     fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0           0  2018-12-15                 NK                 NK          NK
# 1           1  2018-12-16                 UA       UA_CODESHARE          UA
# 2           2  2018-12-15                 NK                 NK          NK
# 3           3  2018-12-15                 NK                 NK          NK
# 4           4  2018-12-15                 NK                 NK          NK
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                 393                NK   N506NK                393
# 1                4119                EV   N14993               4119
# 2                 443                NK   N681NK                443
# 3                 445                NK   N504NK                445
# 4                 446                NK   N621NK                446
#
#    origin_airport_id  ... dep_hour arr_hour  dep_period arr_period  \
# 0              10397  ...       15       16   Afternoon  Afternoon
# 1              11618  ...       19       21     Evening    Evening
# 2              10821  ...       20       22     Evening    Evening
# 3              11066  ...        6        8     Morning    Morning
# 4              12889  ...        8       14     Morning  Afternoon
#
#         origin_match_code         dest_match_code  origin_weather_condition  \
# 0  ATL2018-12-15Afternoon  MSY2018-12-15Afternoon                     Clear
# 1    EWR2018-12-16Evening    RIC2018-12-16Evening                      Rain
# 2    BWI2018-12-15Evening    FLL2018-12-15Evening                      Rain
# 3    CMH2018-12-15Morning    FLL2018-12-15Morning                     Clear
# 4    LAS2018-12-15Morning  ORD2018-12-15Afternoon                     Clear
#
#    origin_weather_severity  dest_weather_condition  dest_weather_severity
# 0                    Light                   Clear                  Light
# 1                 Moderate                   Clear                  Light
# 2                    Light                    Rain                  Light
# 3                    Light                   Clear                  Light
# 4                    Light                   Clear                  Light
#
# [5 rows x 53 columns]

# %%
# Write the data to a new csv
data.to_csv('data/flights_weather.csv')
