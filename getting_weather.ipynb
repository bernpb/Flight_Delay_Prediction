# %%
# Import pandas for df manipulations
import pandas as pd

# %%
# Load the datasets
weather = pd.read_csv('WeatherEvents_Jan2016-Dec2020.csv')
data = pd.read_csv('data/flights.csv', low_memory = False)

# %%
# Inspect the data dataframe
data.head()
# Out:
#    Unnamed: 0     fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0           0  2019-01-01                 AA       AA_CODESHARE          AA
# 1           1  2019-01-01                 AA       AA_CODESHARE          AA
# 2           2  2019-01-01                 AA       AA_CODESHARE          AA
# 3           3  2019-01-01                 AA       AA_CODESHARE          AA
# 4           4  2019-01-01                 AA       AA_CODESHARE          AA
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                5606                OH   N575NN               5606
# 1                5607                OH   N254PS               5607
# 2                5607                OH   N254PS               5607
# 3                5608                OH   N710PS               5608
# 4                5610                OH   N515AE               5610
#
#    origin_airport_id  ... distance carrier_delay  weather_delay nas_delay  \
# 0              13577  ...    157.0           NaN            NaN       NaN
# 1              10529  ...    313.0           NaN            NaN       NaN
# 2              11278  ...    313.0           NaN            NaN       NaN
# 3              11278  ...    396.0           NaN            NaN       NaN
# 4              13931  ...    290.0           NaN            NaN       NaN
#
#   security_delay  late_aircraft_delay  first_dep_time  total_add_gtime  \
# 0            NaN                  NaN             NaN              NaN
# 1            NaN                  NaN             NaN              NaN
# 2            NaN                  NaN             NaN              NaN
# 3            NaN                  NaN             NaN              NaN
# 4            NaN                  NaN             NaN              NaN
#
#    longest_add_gtime  no_name
# 0                NaN      NaN
# 1                NaN      NaN
# 2                NaN      NaN
# 3                NaN      NaN
# 4                NaN      NaN
#
# [5 rows x 43 columns]

# %% [markdown]
# Need to make an hour column in data

# %%
# Extract the hour from the flight departure column
def get_hour(time):
    
    """
    Params - A time in format HHMM.0
    
    Returns  the two digits representing the hour of the flight
    """
    
    s = str(int(time))
    if len(s) <= 2:
        return 0
    else:
        return int(s[:-2])
    
# Function to assign a time of day label to the dataframes.  
# Allows for better matching of weather to our flights dataframe
def time_of_day(hour):
    """
    Input an hour of the day.  
    Output Morning, Afternoon, Evening, Night
    """
    if 0 >= hour > 6:
        return 'Night'
    elif 6>= hour > 12:
        return 'Morning'
    elif 12 >= hour > 6:
        return'Afternoon'
    else:
        return 'Evening'

# %%
# Create a column with the hour that the plane departs

data['hour'] = data['crs_dep_time'].apply(get_hour)

# %%
# Create a column that assigns a period of the day to a departure
data['period'] = data['hour'].apply(time_of_day)

# %%
data.head()
# Out:
#    Unnamed: 0     fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0           0  2019-01-01                 AA       AA_CODESHARE          AA
# 1           1  2019-01-01                 AA       AA_CODESHARE          AA
# 2           2  2019-01-01                 AA       AA_CODESHARE          AA
# 3           3  2019-01-01                 AA       AA_CODESHARE          AA
# 4           4  2019-01-01                 AA       AA_CODESHARE          AA
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                5606                OH   N575NN               5606
# 1                5607                OH   N254PS               5607
# 2                5607                OH   N254PS               5607
# 3                5608                OH   N710PS               5608
# 4                5610                OH   N515AE               5610
#
#    origin_airport_id  ... weather_delay nas_delay  security_delay  \
# 0              13577  ...           NaN       NaN             NaN
# 1              10529  ...           NaN       NaN             NaN
# 2              11278  ...           NaN       NaN             NaN
# 3              11278  ...           NaN       NaN             NaN
# 4              13931  ...           NaN       NaN             NaN
#
#   late_aircraft_delay first_dep_time  total_add_gtime  longest_add_gtime  \
# 0                 NaN            NaN              NaN                NaN
# 1                 NaN            NaN              NaN                NaN
# 2                 NaN            NaN              NaN                NaN
# 3                 NaN            NaN              NaN                NaN
# 4                 NaN            NaN              NaN                NaN
#
#    no_name  hour     period
# 0      NaN    21    Evening
# 1      NaN    11  Afternoon
# 2      NaN    10  Afternoon
# 3      NaN    20    Evening
# 4      NaN    12  Afternoon
#
# [5 rows x 45 columns]

# %%
# Build the matchcode variable for the data table
data['match_code'] = data['origin'].astype(str) + data['fl_date'].astype(str) + data['period'].astype(str)

# %%
# Inspect weather
weather.head()
# Out:
#   EventId  Type Severity       StartTime(UTC)         EndTime(UTC)  \
# 0     W-1  Snow    Light  2016-01-06 23:14:00  2016-01-07 00:34:00
# 1     W-2  Snow    Light  2016-01-07 04:14:00  2016-01-07 04:54:00
# 2     W-3  Snow    Light  2016-01-07 05:54:00  2016-01-07 15:34:00
# 3     W-4  Snow    Light  2016-01-08 05:34:00  2016-01-08 05:54:00
# 4     W-5  Snow    Light  2016-01-08 13:54:00  2016-01-08 15:54:00
#
#       TimeZone AirportCode  LocationLat  LocationLng      City    County  \
# 0  US/Mountain        K04V      38.0972    -106.1689  Saguache  Saguache
# 1  US/Mountain        K04V      38.0972    -106.1689  Saguache  Saguache
# 2  US/Mountain        K04V      38.0972    -106.1689  Saguache  Saguache
# 3  US/Mountain        K04V      38.0972    -106.1689  Saguache  Saguache
# 4  US/Mountain        K04V      38.0972    -106.1689  Saguache  Saguache
#
#   State  ZipCode
# 0    CO  81149.0
# 1    CO  81149.0
# 2    CO  81149.0
# 3    CO  81149.0
# 4    CO  81149.0

# %%
# Let's engineer some columns a little bit
weather['date'] = pd.DatetimeIndex(weather['StartTime(UTC)']).date
weather['hour'] = pd.DatetimeIndex(weather['StartTime(UTC)']).hour
weather['period'] = weather['hour'].apply(time_of_day)
weather = weather.drop(columns = ['StartTime(UTC)', 'EndTime(UTC)'])

# %%
# Remove the K prefix from the airport codes
weather['AirportCode'] = weather['AirportCode'].apply(lambda x: x[1:])

# %%
weather[weather['AirportCode'] == 'JFK']
# Out:
#          EventId  Type  Severity    TimeZone AirportCode  LocationLat  \
# 281085  W-281138  Rain     Light  US/Eastern         JFK      40.6392
# 281086  W-281139  Rain     Light  US/Eastern         JFK      40.6392
# 281087  W-281140  Rain  Moderate  US/Eastern         JFK      40.6392
# 281088  W-281141  Rain     Heavy  US/Eastern         JFK      40.6392
# 281089  W-281142  Rain  Moderate  US/Eastern         JFK      40.6392
# ...          ...   ...       ...         ...         ...          ...
# 283842  W-283895  Rain     Light  US/Eastern         JFK      40.6392
# 283843  W-283896  Rain     Light  US/Eastern         JFK      40.6392
# 283844  W-283897  Rain     Light  US/Eastern         JFK      40.6392
# 283845  W-283898  Rain  Moderate  US/Eastern         JFK      40.6392
# 283846  W-283899  Rain     Light  US/Eastern         JFK      40.6392
#
#         LocationLng     City  County State  ZipCode        date  hour  \
# 281085     -73.7639  Jamaica  Queens    NY  11430.0  2016-01-10     3
# 281086     -73.7639  Jamaica  Queens    NY  11430.0  2016-01-10     8
# 281087     -73.7639  Jamaica  Queens    NY  11430.0  2016-01-10     9
# 281088     -73.7639  Jamaica  Queens    NY  11430.0  2016-01-10    10
# 281089     -73.7639  Jamaica  Queens    NY  11430.0  2016-01-10    11
# ...             ...      ...     ...   ...      ...         ...   ...
# 283842     -73.7639  Jamaica  Queens    NY  11430.0  2020-12-25     8
# 283843     -73.7639  Jamaica  Queens    NY  11430.0  2020-12-25    16
# 283844     -73.7639  Jamaica  Queens    NY  11430.0  2020-12-31    10
# 283845     -73.7639  Jamaica  Queens    NY  11430.0  2020-12-31    13
# 283846     -73.7639  Jamaica  Queens    NY  11430.0  2020-12-31    14
#
#            period
# 281085    Evening
# 281086  Afternoon
# 281087  Afternoon
# 281088  Afternoon
# 281089  Afternoon
# ...           ...
# 283842  Afternoon
# 283843    Evening
# 283844  Afternoon
# 283845    Evening
# 283846    Evening
#
# [2762 rows x 14 columns]

# %%
# Encode the match code column to match values to the data dataframe
weather['match_code'] = weather['AirportCode'].astype(str) + weather['date'].astype(str) + weather['period'].astype(str)

# %%
# Drop unnecessary columns

weather = weather.drop(columns = ['EventId',
                                  'TimeZone',
                                 'AirportCode',
                                 'LocationLat',
                                 'LocationLng',
                                 'City',
                                 'County',
                                 'State',
                                 'ZipCode'])

# %%
weather.shape
# Out:
# (6274206, 6)

# %%
weather = weather.drop_duplicates(subset = 'match_code')
weather.shape
# Out:
# (2344678, 6)

# %%
severity_dict = dict(zip(weather['match_code'], weather['Severity']))
condition_dict = dict(zip(weather['match_code'], weather['Type']))

# %%
len(severity_dict)
# Out:
# 2344678

# %%
data['weather_condition'] = data['match_code'].map(condition_dict)
data['weather_severity'] = data['match_code'].map(severity_dict)
data.head()
# Out:
#    Unnamed: 0     fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0           0  2019-01-01                 AA       AA_CODESHARE          AA
# 1           1  2019-01-01                 AA       AA_CODESHARE          AA
# 2           2  2019-01-01                 AA       AA_CODESHARE          AA
# 3           3  2019-01-01                 AA       AA_CODESHARE          AA
# 4           4  2019-01-01                 AA       AA_CODESHARE          AA
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                5606                OH   N575NN               5606
# 1                5607                OH   N254PS               5607
# 2                5607                OH   N254PS               5607
# 3                5608                OH   N710PS               5608
# 4                5610                OH   N515AE               5610
#
#    origin_airport_id  ... late_aircraft_delay first_dep_time  total_add_gtime  \
# 0              13577  ...                 NaN            NaN              NaN
# 1              10529  ...                 NaN            NaN              NaN
# 2              11278  ...                 NaN            NaN              NaN
# 3              11278  ...                 NaN            NaN              NaN
# 4              13931  ...                 NaN            NaN              NaN
#
#   longest_add_gtime no_name  hour     period              match_code  \
# 0               NaN     NaN    21    Evening    MYR2019-01-01Evening
# 1               NaN     NaN    11  Afternoon  BDL2019-01-01Afternoon
# 2               NaN     NaN    10  Afternoon  DCA2019-01-01Afternoon
# 3               NaN     NaN    20    Evening    DCA2019-01-01Evening
# 4               NaN     NaN    12  Afternoon  ORF2019-01-01Afternoon
#
#    weather_condition  weather_severity
# 0                NaN               NaN
# 1               Rain             Light
# 2               Rain             Light
# 3               Rain             Light
# 4                NaN               NaN
#
# [5 rows x 48 columns]

# %%
# Replace NaN weather conditions with 'Clear' and severity with 'Light'
data['weather_condition'].fillna('Clear', inplace=True)
data['weather_severity'].fillna('Light', inplace=True)
data.head()
# Out:
#    Unnamed: 0     fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0           0  2019-01-01                 AA       AA_CODESHARE          AA
# 1           1  2019-01-01                 AA       AA_CODESHARE          AA
# 2           2  2019-01-01                 AA       AA_CODESHARE          AA
# 3           3  2019-01-01                 AA       AA_CODESHARE          AA
# 4           4  2019-01-01                 AA       AA_CODESHARE          AA
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                5606                OH   N575NN               5606
# 1                5607                OH   N254PS               5607
# 2                5607                OH   N254PS               5607
# 3                5608                OH   N710PS               5608
# 4                5610                OH   N515AE               5610
#
#    origin_airport_id  ... late_aircraft_delay first_dep_time  total_add_gtime  \
# 0              13577  ...                 NaN            NaN              NaN
# 1              10529  ...                 NaN            NaN              NaN
# 2              11278  ...                 NaN            NaN              NaN
# 3              11278  ...                 NaN            NaN              NaN
# 4              13931  ...                 NaN            NaN              NaN
#
#   longest_add_gtime no_name  hour     period              match_code  \
# 0               NaN     NaN    21    Evening    MYR2019-01-01Evening
# 1               NaN     NaN    11  Afternoon  BDL2019-01-01Afternoon
# 2               NaN     NaN    10  Afternoon  DCA2019-01-01Afternoon
# 3               NaN     NaN    20    Evening    DCA2019-01-01Evening
# 4               NaN     NaN    12  Afternoon  ORF2019-01-01Afternoon
#
#    weather_condition  weather_severity
# 0              Clear             Light
# 1               Rain             Light
# 2               Rain             Light
# 3               Rain             Light
# 4              Clear             Light
#
# [5 rows x 48 columns]

# %%
data.to_csv('data/flights_weather.csv')

# %%
data.head()
# Out:
#    Unnamed: 0     fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0           0  2019-01-01                 AA       AA_CODESHARE          AA
# 1           1  2019-01-01                 AA       AA_CODESHARE          AA
# 2           2  2019-01-01                 AA       AA_CODESHARE          AA
# 3           3  2019-01-01                 AA       AA_CODESHARE          AA
# 4           4  2019-01-01                 AA       AA_CODESHARE          AA
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                5606                OH   N575NN               5606
# 1                5607                OH   N254PS               5607
# 2                5607                OH   N254PS               5607
# 3                5608                OH   N710PS               5608
# 4                5610                OH   N515AE               5610
#
#    origin_airport_id  ... late_aircraft_delay first_dep_time  total_add_gtime  \
# 0              13577  ...                 NaN            NaN              NaN
# 1              10529  ...                 NaN            NaN              NaN
# 2              11278  ...                 NaN            NaN              NaN
# 3              11278  ...                 NaN            NaN              NaN
# 4              13931  ...                 NaN            NaN              NaN
#
#   longest_add_gtime no_name  hour     period              match_code  \
# 0               NaN     NaN    21    Evening    MYR2019-01-01Evening
# 1               NaN     NaN    11  Afternoon  BDL2019-01-01Afternoon
# 2               NaN     NaN    10  Afternoon  DCA2019-01-01Afternoon
# 3               NaN     NaN    20    Evening    DCA2019-01-01Evening
# 4               NaN     NaN    12  Afternoon  ORF2019-01-01Afternoon
#
#    weather_condition  weather_severity
# 0              Clear             Light
# 1               Rain             Light
# 2               Rain             Light
# 3               Rain             Light
# 4              Clear             Light
#
# [5 rows x 48 columns]
