# %% [markdown]
# #### This notebook is where we will extract the pertinent weather data for the flights TEST data set

# %%
# Import pandas for df manipulations
import pandas as pd 

from functions import get_hour, time_of_day

# %%
# Load the datasets
weather = pd.read_csv('data/WeatherEvents_Jan2016-Dec2020.csv')
fl_data = pd.read_csv('data/flights_test.csv', low_memory = False)

# %%
# Inspect the data dataframe
fl_data.head()
# Out:
#    Unnamed: 0     fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0           0  2020-01-01                 WN                 WN          WN
# 1           1  2020-01-01                 WN                 WN          WN
# 2           2  2020-01-01                 WN                 WN          WN
# 3           3  2020-01-01                 WN                 WN          WN
# 4           4  2020-01-01                 WN                 WN          WN
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                5888                WN   N951WN               5888
# 1                6276                WN   N467WN               6276
# 2                4598                WN   N7885A               4598
# 3                4761                WN   N551WN               4761
# 4                5162                WN   N968WN               5162
#
#    origin_airport_id  ... origin_city_name dest_airport_id  dest  \
# 0              13891  ...      Ontario, CA           14771   SFO
# 1              13891  ...      Ontario, CA           14771   SFO
# 2              13891  ...      Ontario, CA           14831   SJC
# 3              13891  ...      Ontario, CA           14831   SJC
# 4              13891  ...      Ontario, CA           14831   SJC
#
#       dest_city_name crs_dep_time  crs_arr_time  dup crs_elapsed_time  \
# 0  San Francisco, CA         1810          1945    N               95
# 1  San Francisco, CA         1150          1320    N               90
# 2       San Jose, CA         2020          2130    N               70
# 3       San Jose, CA         1340          1455    N               75
# 4       San Jose, CA          915          1035    N               80
#
#    flights  distance
# 0        1       363
# 1        1       363
# 2        1       333
# 3        1       333
# 4        1       333
#
# [5 rows x 21 columns]

# %% [markdown]
# Need to make an hour column in data

# %%
# Create a column with the hour that the plane departs and arrives

fl_data['dep_hour'] = fl_data['crs_dep_time'].apply(get_hour)
fl_data['arr_hour'] = fl_data['crs_arr_time'].apply(get_hour)
fl_data['arr_hour'].dtypes
# Out:
# dtype('int64')

# %%
# Create a column that assigns a period of the day to a departure
fl_data['dep_period'] = fl_data['dep_hour'].apply(time_of_day)
fl_data['arr_period'] = fl_data['arr_hour'].apply(time_of_day)
fl_data['arr_period'].value_counts()
# Out:
# Afternoon    54106
# Evening      50081
# Morning      41772
# Night         4664
# Name: arr_period, dtype: int64

# %%
# Build the matchcode variable for the fl_data table
fl_data['origin_match_code'] = fl_data['origin'].astype(str) + fl_data['fl_date'].astype(str) + fl_data['dep_period'].astype(str)
fl_data['dest_match_code'] = fl_data['dest'].astype(str) + fl_data['fl_date'].astype(str) + fl_data['arr_period'].astype(str)

# %%
# Let's engineer some columns a little bit
weather['date'] = pd.DatetimeIndex(weather['StartTime(UTC)']).date
weather['hour'] = pd.DatetimeIndex(weather['StartTime(UTC)']).hour
weather['period'] = weather['hour'].apply(time_of_day)
weather = weather.drop(columns = ['StartTime(UTC)', 'EndTime(UTC)'])

# %%
# Remove the K prefix from the airport codes
weather['AirportCode'] = weather['AirportCode'].apply(lambda x: x[1:])

# %%
# Encode the match code column to match values to the data dataframe
weather['match_code'] = weather['AirportCode'].astype(str) + weather['date'].astype(str) + weather['period'].astype(str)

# %%
# Drop unnecessary columns

weather = weather.drop(columns = ['EventId',
                                  'TimeZone',
                                 'AirportCode',
                                 'LocationLat',
                                 'LocationLng',
                                 'City',
                                 'County',
                                 'State',
                                 'ZipCode'])

# %%
# Drop duplicate values
weather = weather.drop_duplicates(subset = 'match_code')
weather.shape
# Out:
# (3097656, 6)

# %%
# Create dictionaries for severity and condition with match_code as the key
severity_dict = dict(zip(weather['match_code'], weather['Severity']))
condition_dict = dict(zip(weather['match_code'], weather['Type']))

# %%
len(severity_dict)
# Out:
# 3097656

# %%
# Use the previously created dictionaries to add severity and condition to the flights dataset
fl_data['origin_weather_condition'] = fl_data['origin_match_code'].map(condition_dict)
fl_data['origin_weather_severity'] = fl_data['origin_match_code'].map(severity_dict)
fl_data['dest_weather_condition'] = fl_data['dest_match_code'].map(condition_dict)
fl_data['dest_weather_severity'] = fl_data['dest_match_code'].map(severity_dict)
fl_data.head(25)
# Out:
#     Unnamed: 0     fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0            0  2020-01-01                 WN                 WN          WN
# 1            1  2020-01-01                 WN                 WN          WN
# 2            2  2020-01-01                 WN                 WN          WN
# 3            3  2020-01-01                 WN                 WN          WN
# 4            4  2020-01-01                 WN                 WN          WN
# 5            5  2020-01-01                 WN                 WN          WN
# 6            6  2020-01-01                 WN                 WN          WN
# 7            7  2020-01-01                 WN                 WN          WN
# 8            8  2020-01-01                 WN                 WN          WN
# 9            9  2020-01-01                 WN                 WN          WN
# 10          10  2020-01-01                 WN                 WN          WN
# 11          11  2020-01-01                 WN                 WN          WN
# 12          12  2020-01-01                 WN                 WN          WN
# 13          13  2020-01-01                 WN                 WN          WN
# 14          14  2020-01-01                 WN                 WN          WN
# 15          15  2020-01-01                 WN                 WN          WN
# 16          16  2020-01-01                 WN                 WN          WN
# 17          17  2020-01-01                 WN                 WN          WN
# 18          18  2020-01-01                 WN                 WN          WN
# 19          19  2020-01-01                 WN                 WN          WN
# 20          20  2020-01-01                 WN                 WN          WN
# 21          21  2020-01-01                 WN                 WN          WN
# 22          22  2020-01-01                 WN                 WN          WN
# 23          23  2020-01-01                 WN                 WN          WN
# 24          24  2020-01-01                 WN                 WN          WN
#
#     mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                 5888                WN   N951WN               5888
# 1                 6276                WN   N467WN               6276
# 2                 4598                WN   N7885A               4598
# 3                 4761                WN   N551WN               4761
# 4                 5162                WN   N968WN               5162
# 5                 5684                WN   N7856A               5684
# 6                 6152                WN   N7735A               6152
# 7                 1679                WN   N405WN               1679
# 8                 3479                WN   N489WN               3479
# 9                 4069                WN   N7708E               4069
# 10                4905                WN   N426WN               4905
# 11                4918                WN   N455WN               4918
# 12                5144                WN   N8314L               5144
# 13                5722                WN   N7820L               5722
# 14                3719                WN   N941WN               3719
# 15                4863                WN   N496WN               4863
# 16                4924                WN   N7732A               4924
# 17                5321                WN   N7863A               5321
# 18                4618                WN   N928WN               4618
# 19                5992                WN   N410WN               5992
# 20                1765                WN   N795SW               1765
# 21                4887                WN   N246LV               4887
# 22                4917                WN   N8568Z               4917
# 23                5068                WN   N8658A               5068
# 24                 745                WN   N763SW                745
#
#     origin_airport_id  ... dep_hour arr_hour  dep_period arr_period  \
# 0               13891  ...       18       19     Evening    Evening
# 1               13891  ...       11       13     Morning  Afternoon
# 2               13891  ...       20       21     Evening    Evening
# 3               13891  ...       13       14   Afternoon  Afternoon
# 4               13891  ...        9       10     Morning    Morning
# 5               13891  ...        6        7     Morning    Morning
# 6               13891  ...       16       17   Afternoon  Afternoon
# 7               13891  ...       15       16   Afternoon  Afternoon
# 8               13891  ...       12       13   Afternoon  Afternoon
# 9               13891  ...        7        9     Morning    Morning
# 10              13891  ...       10       11     Morning    Morning
# 11              13891  ...       20       21     Evening    Evening
# 12              13891  ...       22        0     Evening      Night
# 13              13891  ...       18       19     Evening    Evening
# 14              13931  ...       11       12     Morning  Afternoon
# 15              13931  ...        6        7     Morning    Morning
# 16              13931  ...       20       21     Evening    Evening
# 17              13931  ...       17       18   Afternoon    Evening
# 18              13931  ...       10       12     Morning  Afternoon
# 19              13931  ...       16       18   Afternoon    Evening
# 20              14027  ...       13       14   Afternoon  Afternoon
# 21              14027  ...        7        9     Morning    Morning
# 22              14027  ...       17       20   Afternoon    Evening
# 23              14027  ...       11       13     Morning  Afternoon
# 24              14027  ...        7       10     Morning    Morning
#
#          origin_match_code         dest_match_code  origin_weather_condition  \
# 0     ONT2020-01-01Evening    SFO2020-01-01Evening                       NaN
# 1     ONT2020-01-01Morning  SFO2020-01-01Afternoon                       NaN
# 2     ONT2020-01-01Evening    SJC2020-01-01Evening                       NaN
# 3   ONT2020-01-01Afternoon  SJC2020-01-01Afternoon                       NaN
# 4     ONT2020-01-01Morning    SJC2020-01-01Morning                       NaN
# 5     ONT2020-01-01Morning    SJC2020-01-01Morning                       NaN
# 6   ONT2020-01-01Afternoon  SJC2020-01-01Afternoon                       NaN
# 7   ONT2020-01-01Afternoon  SMF2020-01-01Afternoon                       NaN
# 8   ONT2020-01-01Afternoon  SMF2020-01-01Afternoon                       NaN
# 9     ONT2020-01-01Morning    SMF2020-01-01Morning                       NaN
# 10    ONT2020-01-01Morning    SMF2020-01-01Morning                       NaN
# 11    ONT2020-01-01Evening    SMF2020-01-01Evening                       NaN
# 12    ONT2020-01-01Evening      SMF2020-01-01Night                       NaN
# 13    ONT2020-01-01Evening    SMF2020-01-01Evening                       NaN
# 14    ORF2020-01-01Morning  BWI2020-01-01Afternoon                       NaN
# 15    ORF2020-01-01Morning    BWI2020-01-01Morning                       NaN
# 16    ORF2020-01-01Evening    BWI2020-01-01Evening                       NaN
# 17  ORF2020-01-01Afternoon    BWI2020-01-01Evening                       NaN
# 18    ORF2020-01-01Morning  MCO2020-01-01Afternoon                       NaN
# 19  ORF2020-01-01Afternoon    MDW2020-01-01Evening                       NaN
# 20  PBI2020-01-01Afternoon  ATL2020-01-01Afternoon                       NaN
# 21    PBI2020-01-01Morning    BWI2020-01-01Morning                       NaN
# 22  PBI2020-01-01Afternoon    BWI2020-01-01Evening                       NaN
# 23    PBI2020-01-01Morning  BWI2020-01-01Afternoon                       NaN
# 24    PBI2020-01-01Morning    ISP2020-01-01Morning                       NaN
#
#    origin_weather_severity  dest_weather_condition  dest_weather_severity
# 0                      NaN                     NaN                    NaN
# 1                      NaN                     NaN                    NaN
# 2                      NaN                     NaN                    NaN
# 3                      NaN                     NaN                    NaN
# 4                      NaN                     NaN                    NaN
# 5                      NaN                     NaN                    NaN
# 6                      NaN                     NaN                    NaN
# 7                      NaN                     Fog               Moderate
# 8                      NaN                     Fog               Moderate
# 9                      NaN                     NaN                    NaN
# 10                     NaN                     NaN                    NaN
# 11                     NaN                     Fog               Moderate
# 12                     NaN                     NaN                    NaN
# 13                     NaN                     Fog               Moderate
# 14                     NaN                     NaN                    NaN
# 15                     NaN                     NaN                    NaN
# 16                     NaN                     NaN                    NaN
# 17                     NaN                     NaN                    NaN
# 18                     NaN                     NaN                    NaN
# 19                     NaN                     NaN                    NaN
# 20                     NaN                     NaN                    NaN
# 21                     NaN                     NaN                    NaN
# 22                     NaN                     NaN                    NaN
# 23                     NaN                     NaN                    NaN
# 24                     NaN                     NaN                    NaN
#
# [25 rows x 31 columns]

# %%
fl_data.isna().sum()
# Out:
# Unnamed: 0                       0
# fl_date                          0
# mkt_unique_carrier               0
# branded_code_share               0
# mkt_carrier                      0
# mkt_carrier_fl_num               0
# op_unique_carrier                0
# tail_num                       124
# op_carrier_fl_num                0
# origin_airport_id                0
# origin                           0
# origin_city_name                 0
# dest_airport_id                  0
# dest                             0
# dest_city_name                   0
# crs_dep_time                     0
# crs_arr_time                     0
# dup                              0
# crs_elapsed_time                 0
# flights                          0
# distance                         0
# dep_hour                         0
# arr_hour                         0
# dep_period                       0
# arr_period                       0
# origin_match_code                0
# dest_match_code                  0
# origin_weather_condition    121777
# origin_weather_severity     121777
# dest_weather_condition      121638
# dest_weather_severity       121638
# dtype: int64

# %%
# Replace NaN weather conditions with 'Clear' and severity with 'Light'
fl_data['origin_weather_condition'].fillna('Clear', inplace=True)
fl_data['origin_weather_severity'].fillna('Light', inplace=True)
fl_data['dest_weather_condition'].fillna('Clear', inplace=True)
fl_data['dest_weather_severity'].fillna('Light', inplace=True)
fl_data.head()
# Out:
#    Unnamed: 0     fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0           0  2020-01-01                 WN                 WN          WN
# 1           1  2020-01-01                 WN                 WN          WN
# 2           2  2020-01-01                 WN                 WN          WN
# 3           3  2020-01-01                 WN                 WN          WN
# 4           4  2020-01-01                 WN                 WN          WN
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                5888                WN   N951WN               5888
# 1                6276                WN   N467WN               6276
# 2                4598                WN   N7885A               4598
# 3                4761                WN   N551WN               4761
# 4                5162                WN   N968WN               5162
#
#    origin_airport_id  ... dep_hour arr_hour  dep_period arr_period  \
# 0              13891  ...       18       19     Evening    Evening
# 1              13891  ...       11       13     Morning  Afternoon
# 2              13891  ...       20       21     Evening    Evening
# 3              13891  ...       13       14   Afternoon  Afternoon
# 4              13891  ...        9       10     Morning    Morning
#
#         origin_match_code         dest_match_code  origin_weather_condition  \
# 0    ONT2020-01-01Evening    SFO2020-01-01Evening                     Clear
# 1    ONT2020-01-01Morning  SFO2020-01-01Afternoon                     Clear
# 2    ONT2020-01-01Evening    SJC2020-01-01Evening                     Clear
# 3  ONT2020-01-01Afternoon  SJC2020-01-01Afternoon                     Clear
# 4    ONT2020-01-01Morning    SJC2020-01-01Morning                     Clear
#
#   origin_weather_severity  dest_weather_condition  dest_weather_severity
# 0                   Light                   Clear                  Light
# 1                   Light                   Clear                  Light
# 2                   Light                   Clear                  Light
# 3                   Light                   Clear                  Light
# 4                   Light                   Clear                  Light
#
# [5 rows x 31 columns]

# %%
fl_data['dest_weather_condition'].value_counts()
# Out:
# Clear            121638
# Rain              16850
# Fog                6922
# Snow               4605
# Cold                343
# Storm               258
# Precipitation         6
# Hail                  1
# Name: dest_weather_condition, dtype: int64

# %%
# Write the data to a new csv
fl_data.to_csv('data/flights_test_weather.csv')
